# %%
# Dataset link below.

# %%
https://www.kaggle.com/datasets/waqi786/ai-generated-art-trends

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\GOLLA RAVI TEJA\Downloads\archive (5)\ai_generated_art_trends_2024.csv")

# %%
df.head()
# Out:
#   Artwork_ID   Artist_Name      Art_Style Creation_Date         Medium  \
# 0  ART-00001        DALL-E     Conceptual    2023-03-11        Collage
# 1  ART-00002  AbstractoBot       Futurism    2022-11-27      Oil Paint
# 2  ART-00003       Vincent       Futurism    2024-03-13       Charcoal
# 3  ART-00004    ArtBreeder  Impressionism    2022-09-12  Pencil Sketch
# 4  ART-00005        DALL-E     Surrealism    2022-12-05        Collage
#
#    Tools_Used  Popularity_Score         Region   Art_Genre    Platform  \
# 0    GANPaint           1604.25  South America       Urban   Instagram
# 1  MidJourney           4162.12  North America    Abstract    Dribbble
# 2    GANPaint           2989.38         Europe   Mythology      Reddit
# 3  ArtBreeder           2985.97         Europe  Still Life      Tumblr
# 4   DeepDream           2035.18           Asia  Conceptual  DeviantArt
#
#                                          Description  \
# 0  A mesmerizing piece of art that blends traditi...
# 1  A mesmerizing piece of art that blends traditi...
# 2  A mesmerizing piece of art that blends traditi...
# 3  A mesmerizing piece of art that blends traditi...
# 4  A mesmerizing piece of art that blends traditi...
#
#                                Image_URL
# 0  https://example.com/artwork/00001.jpg
# 1  https://example.com/artwork/00002.jpg
# 2  https://example.com/artwork/00003.jpg
# 3  https://example.com/artwork/00004.jpg
# 4  https://example.com/artwork/00005.jpg

# %%
# Questions on dataset

# %% [markdown]
# ### 1.What are the different art styles present in the dataset?

# %%
# code here.
df['Art_Style'].unique()
# Out:
# array(['Conceptual', 'Futurism', 'Impressionism', 'Surrealism',
#        'Abstract', 'Realism', 'Minimalism', 'Pop Art', 'Cubism',
#        'Expressionism'], dtype=object)

# %%
df['Art_Style'].value_counts()
# Out:
# Art_Style
# Cubism           1050
# Realism          1022
# Expressionism    1021
# Futurism         1016
# Pop Art          1008
# Impressionism     996
# Minimalism        995
# Surrealism        974
# Conceptual        969
# Abstract          949
# Name: count, dtype: int64

# %% [markdown]
# ### 2.How many artworks were created in the year 2023?

# %%
# code here.
df['Creation_Date']
# Out:
# 0       2023-03-11
# 1       2022-11-27
# 2       2024-03-13
# 3       2022-09-12
# 4       2022-12-05
#            ...
# 9995    2024-01-22
# 9996    2023-04-05
# 9997    2023-01-27
# 9998    2022-10-04
# 9999    2022-12-07
# Name: Creation_Date, Length: 10000, dtype: object

# %%
df['Creation_Date'] = pd.to_datetime(df['Creation_Date'])

# %%
df[df['Creation_Date'].dt.year == 2023]
# Out:
#      Artwork_ID  Artist_Name      Art_Style Creation_Date         Medium  \
# 0     ART-00001       DALL-E     Conceptual    2023-03-11        Collage
# 8     ART-00009    PicassoAI        Realism    2023-01-07       Charcoal
# 9     ART-00010   DaVinciNet  Impressionism    2023-09-13     Watercolor
# 10    ART-00011       DALL-E  Impressionism    2023-09-05        Collage
# 11    ART-00012  AIArtist123     Minimalism    2023-01-24    Mixed Media
# ...         ...          ...            ...           ...            ...
# 9991  ART-09992   MidJourney     Minimalism    2023-04-12            Ink
# 9993  ART-09994   MidJourney       Futurism    2023-12-26        Collage
# 9994  ART-09995       DALL-E        Pop Art    2023-03-24            Ink
# 9996  ART-09997    RenoirBot        Pop Art    2023-04-05  Acrylic Paint
# 9997  ART-09998   ArtBreeder       Futurism    2023-01-27       3D Model
#
#       Tools_Used  Popularity_Score         Region   Art_Genre    Platform  \
# 0       GANPaint           1604.25  South America       Urban   Instagram
# 8      DeepDream           2262.06         Europe  Still Life     Behance
# 9         DALL-E           1188.63  North America    Abstract     Twitter
# 10     DeepDream           2911.45         Africa       Urban    Dribbble
# 11     DeepDream           3220.19  North America    Portrait      Flickr
# ...          ...               ...            ...         ...         ...
# 9991  MidJourney           1019.15         Africa    Abstract     Behance
# 9993   DeepDream           2965.69         Europe    Abstract     Twitter
# 9994      DALL-E           3149.51        Oceania      Nature  DeviantArt
# 9996    GANPaint           4715.45        Oceania   Landscape   Instagram
# 9997   DeepDream            741.83         Europe  Conceptual     Behance
#
#                                             Description  \
# 0     A mesmerizing piece of art that blends traditi...
# 8     A mesmerizing piece of art that blends traditi...
# 9     A mesmerizing piece of art that blends traditi...
# 10    A mesmerizing piece of art that blends traditi...
# 11    A mesmerizing piece of art that blends traditi...
# ...                                                 ...
# 9991  A mesmerizing piece of art that blends traditi...
# 9993  A mesmerizing piece of art that blends traditi...
# 9994  A mesmerizing piece of art that blends traditi...
# 9996  A mesmerizing piece of art that blends traditi...
# 9997  A mesmerizing piece of art that blends traditi...
#
#                                   Image_URL
# 0     https://example.com/artwork/00001.jpg
# 8     https://example.com/artwork/00009.jpg
# 9     https://example.com/artwork/00010.jpg
# 10    https://example.com/artwork/00011.jpg
# 11    https://example.com/artwork/00012.jpg
# ...                                     ...
# 9991  https://example.com/artwork/09992.jpg
# 9993  https://example.com/artwork/09994.jpg
# 9994  https://example.com/artwork/09995.jpg
# 9996  https://example.com/artwork/09997.jpg
# 9997  https://example.com/artwork/09998.jpg
#
# [5079 rows x 12 columns]

# %% [markdown]
# ### 3.Find all artworks that have a "Popularity_Score" greater than 4000.

# %%
# code here.
df['Popularity_Score']
# Out:
# 0       1604.25
# 1       4162.12
# 2       2989.38
# 3       2985.97
# 4       2035.18
#          ...
# 9995    3886.42
# 9996    4715.45
# 9997     741.83
# 9998    2229.60
# 9999    3815.99
# Name: Popularity_Score, Length: 10000, dtype: float64

# %%
df[df["Popularity_Score"]>4000]
# Out:
#      Artwork_ID   Artist_Name      Art_Style Creation_Date         Medium  \
# 1     ART-00002  AbstractoBot       Futurism    2022-11-27      Oil Paint
# 5     ART-00006        DALL-E       Futurism    2022-12-13      Oil Paint
# 7     ART-00008        DALL-E  Impressionism    2024-07-22       3D Model
# 19    ART-00020     PicassoAI     Minimalism    2022-10-07       3D Model
# 35    ART-00036       Vincent     Conceptual    2023-09-03  Pencil Sketch
# ...         ...           ...            ...           ...            ...
# 9972  ART-09973        DALL-E  Expressionism    2024-01-19  Acrylic Paint
# 9975  ART-09976    ArtBreeder  Impressionism    2023-04-03  Pencil Sketch
# 9978  ART-09979  AbstractoBot       Futurism    2024-03-07        Collage
# 9981  ART-09982        DALL-E     Minimalism    2023-06-13     Watercolor
# 9996  ART-09997     RenoirBot        Pop Art    2023-04-05  Acrylic Paint
#
#       Tools_Used  Popularity_Score         Region   Art_Genre    Platform  \
# 1     MidJourney           4162.12  North America    Abstract    Dribbble
# 5         DALL-E           4535.59           Asia    Abstract   Instagram
# 7      DeepDream           4989.07           Asia   Landscape   Instagram
# 19      GANPaint           4899.42         Africa  Conceptual     Behance
# 35    MidJourney           4992.66         Europe      Nature  DeviantArt
# ...          ...               ...            ...         ...         ...
# 9972   DeepDream           4277.85  North America     Fantasy   Instagram
# 9975  ArtBreeder           4273.38         Europe    Portrait     Twitter
# 9978  ArtBreeder           4487.09         Europe   Mythology     Twitter
# 9981    GANPaint           4045.10         Europe  Still Life  ArtStation
# 9996    GANPaint           4715.45        Oceania   Landscape   Instagram
#
#                                             Description  \
# 1     A mesmerizing piece of art that blends traditi...
# 5     A mesmerizing piece of art that blends traditi...
# 7     A mesmerizing piece of art that blends traditi...
# 19    A mesmerizing piece of art that blends traditi...
# 35    A mesmerizing piece of art that blends traditi...
# ...                                                 ...
# 9972  A mesmerizing piece of art that blends traditi...
# 9975  A mesmerizing piece of art that blends traditi...
# 9978  A mesmerizing piece of art that blends traditi...
# 9981  A mesmerizing piece of art that blends traditi...
# 9996  A mesmerizing piece of art that blends traditi...
#
#                                   Image_URL
# 1     https://example.com/artwork/00002.jpg
# 5     https://example.com/artwork/00006.jpg
# 7     https://example.com/artwork/00008.jpg
# 19    https://example.com/artwork/00020.jpg
# 35    https://example.com/artwork/00036.jpg
# ...                                     ...
# 9972  https://example.com/artwork/09973.jpg
# 9975  https://example.com/artwork/09976.jpg
# 9978  https://example.com/artwork/09979.jpg
# 9981  https://example.com/artwork/09982.jpg
# 9996  https://example.com/artwork/09997.jpg
#
# [2020 rows x 12 columns]

# %% [markdown]
# ### 4.Calculate the total number of artworks for each "Region".

# %%
# code here
df['Artwork_ID']
# Out:
# 0       ART-00001
# 1       ART-00002
# 2       ART-00003
# 3       ART-00004
# 4       ART-00005
#           ...
# 9995    ART-09996
# 9996    ART-09997
# 9997    ART-09998
# 9998    ART-09999
# 9999    ART-10000
# Name: Artwork_ID, Length: 10000, dtype: object

# %%
df.groupby('Region')['Artwork_ID'].count()
# Out:
# Region
# Africa           1636
# Asia             1648
# Europe           1700
# North America    1659
# Oceania          1629
# South America    1728
# Name: Artwork_ID, dtype: int64

# %% [markdown]
# ### 5.What is the average "Popularity_Score" of artworks in the "Futurism" art style?

# %%
df['Popularity_Score']
# Out:
# 0       1604.25
# 1       4162.12
# 2       2989.38
# 3       2985.97
# 4       2035.18
#          ...
# 9995    3886.42
# 9996    4715.45
# 9997     741.83
# 9998    2229.60
# 9999    3815.99
# Name: Popularity_Score, Length: 10000, dtype: float64

# %%
# code here.
Futurism_artstyle = df[df['Art_Style']=='Futurism']

# %%
Futurism_artstyle['Popularity_Score'].mean()
# Out:
# 2522.9186909448817

# %% [markdown]
# ### 6.Sort the artworks by "Popularity_Score" and display the top 10 most popular artworks.

# %%
# code here.
top_popscore = df.sort_values(by='Popularity_Score', ascending=False)

# %%
top_popscore.head(10)
# Out:
#      Artwork_ID       Artist_Name      Art_Style Creation_Date         Medium  \
# 9119  ART-09120     NeoSurrealist        Realism    2023-10-23            Ink
# 612   ART-00613       AIArtist123     Conceptual    2024-03-15        Digital
# 4358  ART-04359     NeoSurrealist       Abstract    2023-04-24       Charcoal
# 7260  ART-07261         RenoirBot  Expressionism    2023-09-24  Acrylic Paint
# 4490  ART-04491  GenerativeGenius        Pop Art    2023-09-12       3D Model
# 1239  ART-01240         PicassoAI       Abstract    2022-10-11       3D Model
# 4205  ART-04206     NeoSurrealist  Impressionism    2023-01-09  Acrylic Paint
# 1620  ART-01621            DALL-E       Abstract    2022-12-15     Watercolor
# 8587  ART-08588         RenoirBot  Expressionism    2024-05-07    Mixed Media
# 6499  ART-06500            DALL-E       Futurism    2023-01-30    Mixed Media
#
#       Tools_Used  Popularity_Score         Region   Art_Genre    Platform  \
# 9119  ArtBreeder           4999.62  South America     Fantasy     Behance
# 612   ArtBreeder           4999.50  South America   Mythology  ArtStation
# 4358      DALL-E           4999.33  North America    Abstract   Instagram
# 7260      DALL-E           4999.04        Oceania       Urban      Flickr
# 4490    GANPaint           4997.50  North America     Fantasy      Flickr
# 1239    GANPaint           4995.40         Europe      Sci-Fi     Behance
# 4205  ArtBreeder           4994.38  North America      Nature    Dribbble
# 1620  ArtBreeder           4994.25  South America  Still Life     Twitter
# 8587      DALL-E           4993.96        Oceania       Urban    Dribbble
# 6499  ArtBreeder           4993.89         Africa    Abstract   Instagram
#
#                                             Description  \
# 9119  A mesmerizing piece of art that blends traditi...
# 612   A mesmerizing piece of art that blends traditi...
# 4358  A mesmerizing piece of art that blends traditi...
# 7260  A mesmerizing piece of art that blends traditi...
# 4490  A mesmerizing piece of art that blends traditi...
# 1239  A mesmerizing piece of art that blends traditi...
# 4205  A mesmerizing piece of art that blends traditi...
# 1620  A mesmerizing piece of art that blends traditi...
# 8587  A mesmerizing piece of art that blends traditi...
# 6499  A mesmerizing piece of art that blends traditi...
#
#                                   Image_URL
# 9119  https://example.com/artwork/09120.jpg
# 612   https://example.com/artwork/00613.jpg
# 4358  https://example.com/artwork/04359.jpg
# 7260  https://example.com/artwork/07261.jpg
# 4490  https://example.com/artwork/04491.jpg
# 1239  https://example.com/artwork/01240.jpg
# 4205  https://example.com/artwork/04206.jpg
# 1620  https://example.com/artwork/01621.jpg
# 8587  https://example.com/artwork/08588.jpg
# 6499  https://example.com/artwork/06500.jpg

# %% [markdown]
# ### 7.Group the artworks by "Artist_Name" and calculate the average "Popularity_Score" for each artist.

# %%
df.groupby('Artist_Name')['Popularity_Score'].mean()
# Out:
# Artist_Name
# AIArtist123         2402.990198
# AbstractoBot        2438.509925
# ArtBreeder          2418.609719
# DALL-E              2490.125094
# DaVinciNet          2558.465712
# DeepArt             2591.649838
# DeepDream           2498.119969
# GANPaint            2549.093847
# GenerativeGenius    2566.583829
# MidJourney          2471.910375
# MonaBot             2487.533201
# NeoSurrealist       2480.058879
# PicassoAI           2510.702214
# RenoirBot           2598.548453
# Vincent             2563.740516
# Name: Popularity_Score, dtype: float64

# %% [markdown]
# ### 8.Group the data by "Art_Style" and count the number of artworks in each style.

# %%
# code here.
df.groupby('Art_Style')['Artwork_ID'].count()
# Out:
# Art_Style
# Abstract          949
# Conceptual        969
# Cubism           1050
# Expressionism    1021
# Futurism         1016
# Impressionism     996
# Minimalism        995
# Pop Art          1008
# Realism          1022
# Surrealism        974
# Name: Artwork_ID, dtype: int64

# %% [markdown]
# ### 9.How many artworks were created using each medium?

# %%
# code here.
df.groupby('Medium')['Artwork_ID'].count()
# Out:
# Medium
# 3D Model          958
# Acrylic Paint    1025
# Charcoal          983
# Collage           998
# Digital           999
# Ink               959
# Mixed Media      1041
# Oil Paint         979
# Pencil Sketch    1048
# Watercolor       1010
# Name: Artwork_ID, dtype: int64

# %%
df['Medium'].nunique()
# Out:
# 10

# %% [markdown]
# ### 10.Check for any missing values in the dataset.

# %%
# code here.
df.isnull().sum()
# Out:
# Artwork_ID          0
# Artist_Name         0
# Art_Style           0
# Creation_Date       0
# Medium              0
# Tools_Used          0
# Popularity_Score    0
# Region              0
# Art_Genre           0
# Platform            0
# Description         0
# Image_URL           0
# dtype: int64

# %%
df.isna().sum()
# Out:
# Artwork_ID          0
# Artist_Name         0
# Art_Style           0
# Creation_Date       0
# Medium              0
# Tools_Used          0
# Popularity_Score    0
# Region              0
# Art_Genre           0
# Platform            0
# Description         0
# Image_URL           0
# dtype: int64

# %% [markdown]
# ### 11.Calculate the standard deviation of the "Popularity_Score" for each "Art_Style".

# %%
# code here.
df.groupby('Art_Style')['Popularity_Score'].std()
# Out:
# Art_Style
# Abstract         1457.836653
# Conceptual       1426.173350
# Cubism           1451.142056
# Expressionism    1465.789492
# Futurism         1422.966785
# Impressionism    1391.974547
# Minimalism       1434.589041
# Pop Art          1435.627543
# Realism          1411.020359
# Surrealism       1409.886662
# Name: Popularity_Score, dtype: float64

# %% [markdown]
# ### 12.Calculate the mean, median, and standard deviation of the "Popularity_Score" for artworks created using "GANPaint"

# %%
# code here.
df[df['Tools_Used']=='GANPaint']
# Out:
#      Artwork_ID       Artist_Name      Art_Style Creation_Date         Medium  \
# 0     ART-00001            DALL-E     Conceptual    2023-03-11        Collage
# 2     ART-00003           Vincent       Futurism    2024-03-13       Charcoal
# 19    ART-00020         PicassoAI     Minimalism    2022-10-07       3D Model
# 20    ART-00021       AIArtist123  Impressionism    2023-10-25  Acrylic Paint
# 23    ART-00024        MidJourney  Expressionism    2024-04-24        Collage
# ...         ...               ...            ...           ...            ...
# 9981  ART-09982            DALL-E     Minimalism    2023-06-13     Watercolor
# 9988  ART-09989        DaVinciNet       Abstract    2023-11-09  Pencil Sketch
# 9995  ART-09996         RenoirBot     Conceptual    2024-01-22      Oil Paint
# 9996  ART-09997         RenoirBot        Pop Art    2023-04-05  Acrylic Paint
# 9998  ART-09999  GenerativeGenius         Cubism    2022-10-04  Acrylic Paint
#
#      Tools_Used  Popularity_Score         Region   Art_Genre    Platform  \
# 0      GANPaint           1604.25  South America       Urban   Instagram
# 2      GANPaint           2989.38         Europe   Mythology      Reddit
# 19     GANPaint           4899.42         Africa  Conceptual     Behance
# 20     GANPaint           2511.22           Asia   Mythology    Dribbble
# 23     GANPaint           3620.88           Asia      Sci-Fi   Pinterest
# ...         ...               ...            ...         ...         ...
# 9981   GANPaint           4045.10         Europe  Still Life  ArtStation
# 9988   GANPaint           1734.75         Europe     Fantasy   Pinterest
# 9995   GANPaint           3886.42        Oceania      Nature  DeviantArt
# 9996   GANPaint           4715.45        Oceania   Landscape   Instagram
# 9998   GANPaint           2229.60         Africa    Portrait  DeviantArt
#
#                                             Description  \
# 0     A mesmerizing piece of art that blends traditi...
# 2     A mesmerizing piece of art that blends traditi...
# 19    A mesmerizing piece of art that blends traditi...
# 20    A mesmerizing piece of art that blends traditi...
# 23    A mesmerizing piece of art that blends traditi...
# ...                                                 ...
# 9981  A mesmerizing piece of art that blends traditi...
# 9988  A mesmerizing piece of art that blends traditi...
# 9995  A mesmerizing piece of art that blends traditi...
# 9996  A mesmerizing piece of art that blends traditi...
# 9998  A mesmerizing piece of art that blends traditi...
#
#                                   Image_URL
# 0     https://example.com/artwork/00001.jpg
# 2     https://example.com/artwork/00003.jpg
# 19    https://example.com/artwork/00020.jpg
# 20    https://example.com/artwork/00021.jpg
# 23    https://example.com/artwork/00024.jpg
# ...                                     ...
# 9981  https://example.com/artwork/09982.jpg
# 9988  https://example.com/artwork/09989.jpg
# 9995  https://example.com/artwork/09996.jpg
# 9996  https://example.com/artwork/09997.jpg
# 9998  https://example.com/artwork/09999.jpg
#
# [2022 rows x 12 columns]

# %%
df[df['Tools_Used']=='GANPaint']['Popularity_Score'].agg({'mean','median','std'})
# Out:
# median    2483.720000
# mean      2524.002265
# std       1424.863456
# Name: Popularity_Score, dtype: float64

# %%
df.groupby('Tools_Used')['Popularity_Score'].agg({'mean','median','std'})
# Out:
#               median         mean          std
# Tools_Used
# ArtBreeder  2513.975  2510.658981  1454.593612
# DALL-E      2480.510  2508.350313  1438.131721
# DeepDream   2514.390  2499.059026  1418.469243
# GANPaint    2483.720  2524.002265  1424.863456
# MidJourney  2482.500  2498.853931  1420.137355

# %% [markdown]
# ### 13.Count the number of artworks created by each artist

# %%
df['Artist_Name'].value_counts()
# Out:
# Artist_Name
# MidJourney          694
# DALL-E              691
# DaVinciNet          681
# NeoSurrealist       678
# DeepArt             678
# ArtBreeder          675
# GANPaint            668
# RenoirBot           666
# AbstractoBot        665
# PicassoAI           664
# Vincent             659
# AIArtist123         657
# MonaBot             656
# DeepDream           649
# GenerativeGenius    619
# Name: count, dtype: int64

# %% [markdown]
# ### 14.Filter the dataset to show only artworks created in "2024" using "Oil Paint".

# %%
# code here.
df['Medium'].unique()
# Out:
# array(['Collage', 'Oil Paint', 'Charcoal', 'Pencil Sketch', 'Mixed Media',
#        '3D Model', 'Watercolor', 'Digital', 'Acrylic Paint', 'Ink'],
#       dtype=object)

# %%
df[df['Creation_Date'].dt.year==2024][df['Medium']=='Oil Paint']
# Out:
# C:\Users\GOLLA RAVI TEJA\AppData\Local\Temp\ipykernel_18576\4265186511.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df['Creation_Date'].dt.year==2024][df['Medium']=='Oil Paint']
#      Artwork_ID       Artist_Name      Art_Style Creation_Date     Medium  \
# 43    ART-00044         DeepDream       Futurism    2024-07-26  Oil Paint
# 126   ART-00127  GenerativeGenius  Impressionism    2024-01-06  Oil Paint
# 146   ART-00147           MonaBot     Minimalism    2024-05-25  Oil Paint
# 168   ART-00169           MonaBot        Pop Art    2024-05-20  Oil Paint
# 207   ART-00208        MidJourney     Minimalism    2024-01-14  Oil Paint
# ...         ...               ...            ...           ...        ...
# 9843  ART-09844       AIArtist123  Expressionism    2024-06-16  Oil Paint
# 9914  ART-09915      AbstractoBot  Impressionism    2024-01-14  Oil Paint
# 9990  ART-09991            DALL-E     Minimalism    2024-08-15  Oil Paint
# 9992  ART-09993         RenoirBot       Futurism    2024-04-04  Oil Paint
# 9995  ART-09996         RenoirBot     Conceptual    2024-01-22  Oil Paint
#
#       Tools_Used  Popularity_Score         Region   Art_Genre    Platform  \
# 43     DeepDream           4048.81         Africa   Mythology     Behance
# 126   MidJourney           1042.80         Europe      Nature      Reddit
# 146     GANPaint           2736.10         Africa    Portrait     Behance
# 168   ArtBreeder           3305.86         Africa      Nature     Behance
# 207     GANPaint           4860.01  South America   Landscape      Reddit
# ...          ...               ...            ...         ...         ...
# 9843   DeepDream            944.81  North America    Portrait     Twitter
# 9914  ArtBreeder           1184.63  North America  Still Life     Behance
# 9990  MidJourney            574.55           Asia    Abstract   Pinterest
# 9992   DeepDream            385.71           Asia       Urban      Reddit
# 9995    GANPaint           3886.42        Oceania      Nature  DeviantArt
#
#                                             Description  \
# 43    A mesmerizing piece of art that blends traditi...
# 126   A mesmerizing piece of art that blends traditi...
# 146   A mesmerizing piece of art that blends traditi...
# 168   A mesmerizing piece of art that blends traditi...
# 207   A mesmerizing piece of art that blends traditi...
# ...                                                 ...
# 9843  A mesmerizing piece of art that blends traditi...
# 9914  A mesmerizing piece of art that blends traditi...
# 9990  A mesmerizing piece of art that blends traditi...
# 9992  A mesmerizing piece of art that blends traditi...
# 9995  A mesmerizing piece of art that blends traditi...
#
#                                   Image_URL
# 43    https://example.com/artwork/00044.jpg
# 126   https://example.com/artwork/00127.jpg
# 146   https://example.com/artwork/00147.jpg
# 168   https://example.com/artwork/00169.jpg
# 207   https://example.com/artwork/00208.jpg
# ...                                     ...
# 9843  https://example.com/artwork/09844.jpg
# 9914  https://example.com/artwork/09915.jpg
# 9990  https://example.com/artwork/09991.jpg
# 9992  https://example.com/artwork/09993.jpg
# 9995  https://example.com/artwork/09996.jpg
#
# [351 rows x 12 columns]

# %%
df[(df['Creation_Date'].dt.year==2024) & (df['Medium']=='Oil Paint')]
# Out:
#      Artwork_ID       Artist_Name      Art_Style Creation_Date     Medium  \
# 43    ART-00044         DeepDream       Futurism    2024-07-26  Oil Paint
# 126   ART-00127  GenerativeGenius  Impressionism    2024-01-06  Oil Paint
# 146   ART-00147           MonaBot     Minimalism    2024-05-25  Oil Paint
# 168   ART-00169           MonaBot        Pop Art    2024-05-20  Oil Paint
# 207   ART-00208        MidJourney     Minimalism    2024-01-14  Oil Paint
# ...         ...               ...            ...           ...        ...
# 9843  ART-09844       AIArtist123  Expressionism    2024-06-16  Oil Paint
# 9914  ART-09915      AbstractoBot  Impressionism    2024-01-14  Oil Paint
# 9990  ART-09991            DALL-E     Minimalism    2024-08-15  Oil Paint
# 9992  ART-09993         RenoirBot       Futurism    2024-04-04  Oil Paint
# 9995  ART-09996         RenoirBot     Conceptual    2024-01-22  Oil Paint
#
#       Tools_Used  Popularity_Score         Region   Art_Genre    Platform  \
# 43     DeepDream           4048.81         Africa   Mythology     Behance
# 126   MidJourney           1042.80         Europe      Nature      Reddit
# 146     GANPaint           2736.10         Africa    Portrait     Behance
# 168   ArtBreeder           3305.86         Africa      Nature     Behance
# 207     GANPaint           4860.01  South America   Landscape      Reddit
# ...          ...               ...            ...         ...         ...
# 9843   DeepDream            944.81  North America    Portrait     Twitter
# 9914  ArtBreeder           1184.63  North America  Still Life     Behance
# 9990  MidJourney            574.55           Asia    Abstract   Pinterest
# 9992   DeepDream            385.71           Asia       Urban      Reddit
# 9995    GANPaint           3886.42        Oceania      Nature  DeviantArt
#
#                                             Description  \
# 43    A mesmerizing piece of art that blends traditi...
# 126   A mesmerizing piece of art that blends traditi...
# 146   A mesmerizing piece of art that blends traditi...
# 168   A mesmerizing piece of art that blends traditi...
# 207   A mesmerizing piece of art that blends traditi...
# ...                                                 ...
# 9843  A mesmerizing piece of art that blends traditi...
# 9914  A mesmerizing piece of art that blends traditi...
# 9990  A mesmerizing piece of art that blends traditi...
# 9992  A mesmerizing piece of art that blends traditi...
# 9995  A mesmerizing piece of art that blends traditi...
#
#                                   Image_URL
# 43    https://example.com/artwork/00044.jpg
# 126   https://example.com/artwork/00127.jpg
# 146   https://example.com/artwork/00147.jpg
# 168   https://example.com/artwork/00169.jpg
# 207   https://example.com/artwork/00208.jpg
# ...                                     ...
# 9843  https://example.com/artwork/09844.jpg
# 9914  https://example.com/artwork/09915.jpg
# 9990  https://example.com/artwork/09991.jpg
# 9992  https://example.com/artwork/09993.jpg
# 9995  https://example.com/artwork/09996.jpg
#
# [351 rows x 12 columns]

# %% [markdown]
# ### 15.Display all artworks that are either "Futurism" or "Impressionism" and have a "Popularity_Score" below 2000.

# %%
df[(df['Art_Style']=='Futurism') | (df['Art_Style']=='Impressionism') & (df['Popularity_Score']<2000)]
# Out:
#      Artwork_ID       Artist_Name      Art_Style Creation_Date         Medium  \
# 1     ART-00002      AbstractoBot       Futurism    2022-11-27      Oil Paint
# 2     ART-00003           Vincent       Futurism    2024-03-13       Charcoal
# 5     ART-00006            DALL-E       Futurism    2022-12-13      Oil Paint
# 9     ART-00010        DaVinciNet  Impressionism    2023-09-13     Watercolor
# 29    ART-00030  GenerativeGenius       Futurism    2023-04-20  Acrylic Paint
# ...         ...               ...            ...           ...            ...
# 9985  ART-09986         RenoirBot       Futurism    2023-12-30    Mixed Media
# 9986  ART-09987         PicassoAI       Futurism    2024-02-16  Pencil Sketch
# 9992  ART-09993         RenoirBot       Futurism    2024-04-04      Oil Paint
# 9993  ART-09994        MidJourney       Futurism    2023-12-26        Collage
# 9997  ART-09998        ArtBreeder       Futurism    2023-01-27       3D Model
#
#       Tools_Used  Popularity_Score         Region   Art_Genre   Platform  \
# 1     MidJourney           4162.12  North America    Abstract   Dribbble
# 2       GANPaint           2989.38         Europe   Mythology     Reddit
# 5         DALL-E           4535.59           Asia    Abstract  Instagram
# 9         DALL-E           1188.63  North America    Abstract    Twitter
# 29    ArtBreeder            873.77           Asia  Conceptual  Pinterest
# ...          ...               ...            ...         ...        ...
# 9985      DALL-E           2961.29  South America    Abstract     Flickr
# 9986   DeepDream           1722.87           Asia  Still Life    Twitter
# 9992   DeepDream            385.71           Asia       Urban     Reddit
# 9993   DeepDream           2965.69         Europe    Abstract    Twitter
# 9997   DeepDream            741.83         Europe  Conceptual    Behance
#
#                                             Description  \
# 1     A mesmerizing piece of art that blends traditi...
# 2     A mesmerizing piece of art that blends traditi...
# 5     A mesmerizing piece of art that blends traditi...
# 9     A mesmerizing piece of art that blends traditi...
# 29    A mesmerizing piece of art that blends traditi...
# ...                                                 ...
# 9985  A mesmerizing piece of art that blends traditi...
# 9986  A mesmerizing piece of art that blends traditi...
# 9992  A mesmerizing piece of art that blends traditi...
# 9993  A mesmerizing piece of art that blends traditi...
# 9997  A mesmerizing piece of art that blends traditi...
#
#                                   Image_URL
# 1     https://example.com/artwork/00002.jpg
# 2     https://example.com/artwork/00003.jpg
# 5     https://example.com/artwork/00006.jpg
# 9     https://example.com/artwork/00010.jpg
# 29    https://example.com/artwork/00030.jpg
# ...                                     ...
# 9985  https://example.com/artwork/09986.jpg
# 9986  https://example.com/artwork/09987.jpg
# 9992  https://example.com/artwork/09993.jpg
# 9993  https://example.com/artwork/09994.jpg
# 9997  https://example.com/artwork/09998.jpg
#
# [1416 rows x 12 columns]

# %% [markdown]
# ### 16.What is the most popular artwork (highest Popularity_Score)?

# %%
# code here.
df['Popularity_Score']
# Out:
# 0       1604.25
# 1       4162.12
# 2       2989.38
# 3       2985.97
# 4       2035.18
#          ...
# 9995    3886.42
# 9996    4715.45
# 9997     741.83
# 9998    2229.60
# 9999    3815.99
# Name: Popularity_Score, Length: 10000, dtype: float64

# %%
df.loc[df['Popularity_Score'].idxmax()]
# Out:
# Artwork_ID                                                  ART-09120
# Artist_Name                                             NeoSurrealist
# Art_Style                                                     Realism
# Creation_Date                                     2023-10-23 00:00:00
# Medium                                                            Ink
# Tools_Used                                                 ArtBreeder
# Popularity_Score                                              4999.62
# Region                                                  South America
# Art_Genre                                                     Fantasy
# Platform                                                      Behance
# Description         A mesmerizing piece of art that blends traditi...
# Image_URL                       https://example.com/artwork/09120.jpg
# Name: 9119, dtype: object

# %% [markdown]
# ### 17.What is the least popular artwork (lowest Popularity_Score)?

# %%
# code here.
df.loc[df['Popularity_Score'].idxmin()]
# Out:
# Artwork_ID                                                  ART-00910
# Artist_Name                                                 DeepDream
# Art_Style                                                     Realism
# Creation_Date                                     2023-11-01 00:00:00
# Medium                                                            Ink
# Tools_Used                                                  DeepDream
# Popularity_Score                                                50.85
# Region                                                  South America
# Art_Genre                                                    Abstract
# Platform                                                       Tumblr
# Description         A mesmerizing piece of art that blends traditi...
# Image_URL                       https://example.com/artwork/00910.jpg
# Name: 909, dtype: object

# %% [markdown]
# ### 18.What is the most common art genre in Europe?

# %%
# code here.
europe_reg = df[df['Region']=='Europe']

# %%
europe_reg
# Out:
#      Artwork_ID  Artist_Name      Art_Style Creation_Date         Medium  \
# 2     ART-00003      Vincent       Futurism    2024-03-13       Charcoal
# 3     ART-00004   ArtBreeder  Impressionism    2022-09-12  Pencil Sketch
# 8     ART-00009    PicassoAI        Realism    2023-01-07       Charcoal
# 12    ART-00013    PicassoAI        Pop Art    2023-09-23        Digital
# 18    ART-00019  AIArtist123        Realism    2022-12-20  Pencil Sketch
# ...         ...          ...            ...           ...            ...
# 9983  ART-09984   ArtBreeder  Expressionism    2023-02-01  Acrylic Paint
# 9984  ART-09985    DeepDream  Impressionism    2023-04-17       3D Model
# 9988  ART-09989   DaVinciNet       Abstract    2023-11-09  Pencil Sketch
# 9993  ART-09994   MidJourney       Futurism    2023-12-26        Collage
# 9997  ART-09998   ArtBreeder       Futurism    2023-01-27       3D Model
#
#       Tools_Used  Popularity_Score  Region   Art_Genre    Platform  \
# 2       GANPaint           2989.38  Europe   Mythology      Reddit
# 3     ArtBreeder           2985.97  Europe  Still Life      Tumblr
# 8      DeepDream           2262.06  Europe  Still Life     Behance
# 12        DALL-E            531.73  Europe   Landscape     Behance
# 18    MidJourney           1234.05  Europe  Conceptual     Behance
# ...          ...               ...     ...         ...         ...
# 9983  ArtBreeder            696.48  Europe      Sci-Fi  ArtStation
# 9984  ArtBreeder            892.33  Europe       Urban  DeviantArt
# 9988    GANPaint           1734.75  Europe     Fantasy   Pinterest
# 9993   DeepDream           2965.69  Europe    Abstract     Twitter
# 9997   DeepDream            741.83  Europe  Conceptual     Behance
#
#                                             Description  \
# 2     A mesmerizing piece of art that blends traditi...
# 3     A mesmerizing piece of art that blends traditi...
# 8     A mesmerizing piece of art that blends traditi...
# 12    A mesmerizing piece of art that blends traditi...
# 18    A mesmerizing piece of art that blends traditi...
# ...                                                 ...
# 9983  A mesmerizing piece of art that blends traditi...
# 9984  A mesmerizing piece of art that blends traditi...
# 9988  A mesmerizing piece of art that blends traditi...
# 9993  A mesmerizing piece of art that blends traditi...
# 9997  A mesmerizing piece of art that blends traditi...
#
#                                   Image_URL
# 2     https://example.com/artwork/00003.jpg
# 3     https://example.com/artwork/00004.jpg
# 8     https://example.com/artwork/00009.jpg
# 12    https://example.com/artwork/00013.jpg
# 18    https://example.com/artwork/00019.jpg
# ...                                     ...
# 9983  https://example.com/artwork/09984.jpg
# 9984  https://example.com/artwork/09985.jpg
# 9988  https://example.com/artwork/09989.jpg
# 9993  https://example.com/artwork/09994.jpg
# 9997  https://example.com/artwork/09998.jpg
#
# [1700 rows x 12 columns]

# %%
europe_reg['Art_Genre'].value_counts()
# Out:
# Art_Genre
# Portrait      191
# Conceptual    182
# Still Life    180
# Fantasy       180
# Mythology     176
# Landscape     164
# Abstract      164
# Sci-Fi        157
# Urban         157
# Nature        149
# Name: count, dtype: int64

# %%
europe_reg['Art_Genre'].value_counts().idxmax()
# Out:
# 'Portrait'

# %% [markdown]
# ### 19.Export the dataset to a CSV file named "artwork_data.csv".

# %%
# code here.
df.to_csv('artwork_data.csv',index=False)

# %% [markdown]
# ### 20.Group the data by Artist_Name and calculate the total number of artworks created by each artist.

# %%
# code here.
df.groupby('Artist_Name').size()
# Out:
# Artist_Name
# AIArtist123         657
# AbstractoBot        665
# ArtBreeder          675
# DALL-E              691
# DaVinciNet          681
# DeepArt             678
# DeepDream           649
# GANPaint            668
# GenerativeGenius    619
# MidJourney          694
# MonaBot             656
# NeoSurrealist       678
# PicassoAI           664
# RenoirBot           666
# Vincent             659
# dtype: int64
